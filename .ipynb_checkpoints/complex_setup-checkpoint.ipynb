# %% [markdown]
# # Cleaning Crystal Structure

# %%
import nglview
import ipywidgets
import plotly
from plotly import subplots
import plotly.graph_objs as go

pdbCode = "4rc7"
ligandCode = "pl3"
mol_charge = 0

# %%
view = nglview.show_structure_file(f"input/{pdbCode}.pdb")
view.clear_representations()
view.add_representation(repr_type='cartoon', selection='protein', color='sstruc')
view.add_representation(repr_type='ball+stick', radius='0.1', selection='water')
view.add_representation(repr_type='ball+stick', radius='0.5', selection='ligand')
view.add_representation(repr_type='ball+stick', radius='0.5', selection='ion')
view._remote_call('setSize', target='Widget', args=['','600px'])

view
# Out:
# NGLWidget()

# %%
from biobb_structure_utils.utils.remove_pdb_water import remove_pdb_water

nowat_pdb = pdbCode+'.nowat.pdb'

remove_pdb_water(input_pdb_path=f"input/{pdbCode}.pdb",
    output_pdb_path=f"input/{nowat_pdb}")
# Out:
# 2022-06-23 14:59:43,210 [MainThread  ] [INFO ]  check_structure -i input/4rc7.pdb -o input/4rc7.nowat.pdb --force_save water --remove yes
#
# 2022-06-23 14:59:43,213 [MainThread  ] [INFO ]  Exit code 0
#
# 2022-06-23 14:59:43,214 [MainThread  ] [INFO ]  ===============================================================================
# =                   BioBB structure checking utility v3.8.1                   =
# =                 A. Hospital, P. Andrio, J.L. Gelpi 2018-21                  =
# ===============================================================================
#
# Warning: sequence features only available in mmCIF format or with external fasta input
# Structure input/4rc7.pdb loaded
#  Title:
#  Experimental method: unknown
#  Resolution (A): N.A.
#
#  Num. models: 1
#  Num. chains: 1 (A: Protein)
#  Num. residues:  318
#  Num. residues with ins. codes:  0
#  Num. HETATM residues:  98
#  Num. ligands or modified residues:  3
#  Num. water mol.:  95
#  Num. atoms:  1881
# Metal/Ion residues found
# FE2 A1002
# FE2 A1003
# Small mol ligands found
# PL3 A1001
#
# Running water. Options: --remove yes
# 95 Water molecules detected
# 95 Water molecules removed
# Final Num. models: 1
# Final Num. chains: 1 (A: Protein)
# Final Num. residues:  223
# Final Num. residues with ins. codes:  0
# Final Num. HETATM residues:  3
# Final Num. ligands or modified residues:  3
# Final Num. water mol.:  0
# Final Num. atoms:  1786
# Metal/Ion residues found
# FE2 A1002
# FE2 A1003
# Small mol ligands found
# PL3 A1001
# Structure saved on input/4rc7.nowat.pdb
# 0

# %%
from biobb_structure_utils.utils.remove_ligand import remove_ligand

nofe2_pdb = pdbCode+'.noFe2.pdb'

prop = {
    'ligand' : 'FE2'
}

remove_ligand(input_structure_path=f"input/{nowat_pdb}",
    output_structure_path=f"input/{nofe2_pdb}",
    properties=prop)
# Out:
# 2022-06-23 14:59:44,577 [MainThread  ] [INFO ]  PDB format detected, removing all atoms from residues named FE2
# 0

# %%
view = nglview.show_structure_file(f"input/{nofe2_pdb}")
view.clear_representations()
view.add_representation(repr_type='cartoon', selection='protein', color='sstruc')
view.add_representation(repr_type='ball+stick', radius='0.1', selection='water')
view.add_representation(repr_type='ball+stick', radius='0.5', selection='ligand')
view.add_representation(repr_type='ball+stick', radius='0.5', selection='ion')
view._remote_call('setSize', target='Widget', args=['','600px'])

view
# Out:
# NGLWidget()

# %% [markdown]
# # Cleaning Crystal Structure

# %%
# Import module
from biobb_amber.pdb4amber.pdb4amber_run import pdb4amber_run

# Crea# Cleaning Crystal Structurete prop dict and inputs/outputs
output_pdb4amber_path = 'structure.pdb4amber.pdb'

# Create and launch bb
pdb4amber_run(input_pdb_path=f"input/{nofe2_pdb}",
            output_pdb_path=f"input/{output_pdb4amber_path}")
# Out:
# 2022-06-23 14:59:46,416 [MainThread  ] [INFO ]  Creating 9b764467-4ee0-4817-8a97-ad3ccd1e4012 temporary folder
# 2022-06-23 14:59:46,417 [MainThread  ] [INFO ]  Creating command line with instructions and required arguments
# 2022-06-23 14:59:47,461 [MainThread  ] [INFO ]  pdb4amber  -i input/4rc7.noFe2.pdb -o input/structure.pdb4amber.pdb
#
# 2022-06-23 14:59:47,463 [MainThread  ] [INFO ]  Exit code 0
#
# 2022-06-23 14:59:47,464 [MainThread  ] [INFO ]
# ==================================================
# Summary of pdb4amber for: input/4rc7.noFe2.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# PL3
#
# ---------- Mising heavy atom(s)
#
# None
#
# 2022-06-23 14:59:47,465 [MainThread  ] [INFO ]  Removed: 9b764467-4ee0-4817-8a97-ad3ccd1e4012
# 0

# %%
from biobb_structure_utils.utils.extract_heteroatoms import extract_heteroatoms

ligandFile = ligandCode+'.pdb'

prop = {
     'heteroatoms' : [{"name": "PL3"}]
}

extract_heteroatoms(input_structure_path=f"input/{output_pdb4amber_path}",
     output_heteroatom_path=f"input/{ligandFile}",
     properties=prop)
# Out:
# 2022-06-23 15:19:37,425 [MainThread  ] [INFO ]  File input/pl3.pdb created
# 0

# %%
from biobb_chemistry.ambertools.reduce_add_hydrogens import reduce_add_hydrogens

output_reduce_h = ligandCode+'.reduce.H.pdb' 

prop = {
    'build': True,
    'flip': True,
    'rotexist': True,
    'nuclear': True
}

reduce_add_hydrogens(input_path=f"input/{ligandFile}",
                   output_path=f"input/{output_reduce_h}",
                   properties=prop)
# Out:
# 2022-06-23 15:31:14,902 [MainThread  ] [INFO ]  Not using any container
# 2022-06-23 15:31:15,072 [MainThread  ] [INFO ]  reduce -FLIP -NUClear -OH -ROTNH3 -ROTEXist -ALLALT -BUILD input/pl3.pdb > input/pl3.reduce.H.pdb
#
# 2022-06-23 15:31:15,074 [MainThread  ] [INFO ]  Exit code 0
#
# 2022-06-23 15:31:15,076 [MainThread  ] [INFO ]  reduce: version 3.3 06/02/2016, Copyright 1997-2016, J. Michael Word
# Processing file: "input/pl3.pdb"
# Database of HETATM connections: "/Users/ethan/anaconda3/envs/biobb_AMBER_MD//dat/reduce_wwPDB_het_dict.txt"
# VDW dot density = 16/A^2
# Orientation penalty scale = 1 (100%)
# Eliminate contacts within 3 bonds.
# Ignore atoms with |occupancy| <= 0.01 during adjustments.
# Waters ignored if B-Factor >= 40 or |occupancy| < 0.66
# Aromatic rings in amino acids accept hydrogen bonds.
# Building His ring NH Hydrogens.
# Flipping Asn, Gln and His groups.
# For each flip state, bumps where gap is more than 0.4A are indicated with '!'.
# Building or keeping OH & SH Hydrogens.
# Rotating NH3 Hydrogens.
# Not processing Met methyls.
# Rotating pre-existing groups.
# WARNING: atom H1C1 from PL3 will be treated as hydrogen
# WARNING: atom H1C1 from PL3 will be treated as hydrogen
# WARNING: atom H1C2 from PL3 will be treated as hydrogen
# WARNING: atom H1C2 from PL3 will be treated as hydrogen
# WARNING: atom H1C1 from PL3 will be treated as hydrogen
# WARNING: atom H1C2 from PL3 will be treated as hydrogen
# WARNING: atom H2C1 from PL3 will be treated as hydrogen
# WARNING: atom H2C1 from PL3 will be treated as hydrogen
# WARNING: atom H2C2 from PL3 will be treated as hydrogen
# WARNING: atom H2C2 from PL3 will be treated as hydrogen
# WARNING: atom H2C1 from PL3 will be treated as hydrogen
# WARNING: atom H2C2 from PL3 will be treated as hydrogen
# WARNING: atom H3C1 from PL3 will be treated as hydrogen
# WARNING: atom H3C1 from PL3 will be treated as hydrogen
# WARNING: atom H3C2 from PL3 will be treated as hydrogen
# WARNING: atom H3C2 from PL3 will be treated as hydrogen
# WARNING: atom H3C1 from PL3 will be treated as hydrogen
# WARNING: atom H3C2 from PL3 will be treated as hydrogen
# WARNING: atom H4C1 from PL3 will be treated as hydrogen
# WARNING: atom H4C1 from PL3 will be treated as hydrogen
# WARNING: atom H4C2 from PL3 will be treated as hydrogen
# WARNING: atom H4C2 from PL3 will be treated as hydrogen
# WARNING: atom H4C1 from PL3 will be treated as hydrogen
# WARNING: atom H4C2 from PL3 will be treated as hydrogen
# WARNING: atom H6C1 from PL3 will be treated as hydrogen
# WARNING: atom H6C1 from PL3 will be treated as hydrogen
# WARNING: atom H6C2 from PL3 will be treated as hydrogen
# WARNING: atom H6C2 from PL3 will be treated as hydrogen
# WARNING: atom H6C1 from PL3 will be treated as hydrogen
# WARNING: atom H6C2 from PL3 will be treated as hydrogen
# WARNING: atom H7C1 from PL3 will be treated as hydrogen
# WARNING: atom H7C1 from PL3 will be treated as hydrogen
# WARNING: atom H7C2 from PL3 will be treated as hydrogen
# WARNING: atom H7C2 from PL3 will be treated as hydrogen
# WARNING: atom H7C1 from PL3 will be treated as hydrogen
# WARNING: atom H7C2 from PL3 will be treated as hydrogen
# WARNING: atom H8C1 from PL3 will be treated as hydrogen
# WARNING: atom H8C1 from PL3 will be treated as hydrogen
# WARNING: atom H8C2 from PL3 will be treated as hydrogen
# WARNING: atom H8C2 from PL3 will be treated as hydrogen
# WARNING: atom H8C1 from PL3 will be treated as hydrogen
# WARNING: atom H8C2 from PL3 will be treated as hydrogen
# WARNING: atom H9C1 from PL3 will be treated as hydrogen
# WARNING: atom H9C1 from PL3 will be treated as hydrogen
# WARNING: atom H9C2 from PL3 will be treated as hydrogen
# WARNING: atom H9C2 from PL3 will be treated as hydrogen
# WARNING: atom H9C1 from PL3 will be treated as hydrogen
# WARNING: atom H9C2 from PL3 will be treated as hydrogen
# WARNING: atom HAC1 from PL3 will be treated as hydrogen
# WARNING: atom HAC1 from PL3 will be treated as hydrogen
# WARNING: atom HAC2 from PL3 will be treated as hydrogen
# WARNING: atom HAC2 from PL3 will be treated as hydrogen
# WARNING: atom HAC1 from PL3 will be treated as hydrogen
# WARNING: atom HAC2 from PL3 will be treated as hydrogen
# WARNING: atom HBC1 from PL3 will be treated as hydrogen
# WARNING: atom HBC1 from PL3 will be treated as hydrogen
# WARNING: atom HBC2 from PL3 will be treated as hydrogen
# WARNING: atom HBC2 from PL3 will be treated as hydrogen
# WARNING: atom HBC1 from PL3 will be treated as hydrogen
# WARNING: atom HBC2 from PL3 will be treated as hydrogen
# WARNING: atom HCC1 from PL3 will be treated as hydrogen
# WARNING: atom HCC1 from PL3 will be treated as hydrogen
# WARNING: atom HCC2 from PL3 will be treated as hydrogen
# WARNING: atom HCC2 from PL3 will be treated as hydrogen
# WARNING: atom HCC1 from PL3 will be treated as hydrogen
# WARNING: atom HCC2 from PL3 will be treated as hydrogen
# WARNING: atom HCC2 from PL3 will be treated as hydrogen
# WARNING: atom HCC2 from PL3 will be treated as hydrogen
# WARNING: atom HCC1 from PL3 will be treated as hydrogen
# WARNING: atom HCC1 from PL3 will be treated as hydrogen
# WARNING: atom HCC2 from PL3 will be treated as hydrogen
# WARNING: atom HCC1 from PL3 will be treated as hydrogen
# WARNING: atom HBC2 from PL3 will be treated as hydrogen
# WARNING: atom HBC2 from PL3 will be treated as hydrogen
# WARNING: atom HBC1 from PL3 will be treated as hydrogen
# WARNING: atom HBC1 from PL3 will be treated as hydrogen
# WARNING: atom HBC2 from PL3 will be treated as hydrogen
# WARNING: atom HBC1 from PL3 will be treated as hydrogen
# WARNING: atom HAC2 from PL3 will be treated as hydrogen
# WARNING: atom HAC2 from PL3 will be treated as hydrogen
# WARNING: atom HAC1 from PL3 will be treated as hydrogen
# WARNING: atom HAC1 from PL3 will be treated as hydrogen
# WARNING: atom HAC2 from PL3 will be treated as hydrogen
# WARNING: atom HAC1 from PL3 will be treated as hydrogen
# WARNING: atom H9C2 from PL3 will be treated as hydrogen
# WARNING: atom H9C2 from PL3 will be treated as hydrogen
# WARNING: atom H9C1 from PL3 will be treated as hydrogen
# WARNING: atom H9C1 from PL3 will be treated as hydrogen
# WARNING: atom H9C2 from PL3 will be treated as hydrogen
# WARNING: atom H9C1 from PL3 will be treated as hydrogen
# WARNING: atom H8C2 from PL3 will be treated as hydrogen
# WARNING: atom H8C2 from PL3 will be treated as hydrogen
# WARNING: atom H8C1 from PL3 will be treated as hydrogen
# WARNING: atom H8C1 from PL3 will be treated as hydrogen
# WARNING: atom H8C2 from PL3 will be treated as hydrogen
# WARNING: atom H8C1 from PL3 will be treated as hydrogen
# WARNING: atom H7C2 from PL3 will be treated as hydrogen
# WARNING: atom H7C2 from PL3 will be treated as hydrogen
# WARNING: atom H7C1 from PL3 will be treated as hydrogen
# WARNING: atom H7C1 from PL3 will be treated as hydrogen
# WARNING: atom H7C2 from PL3 will be treated as hydrogen
# WARNING: atom H7C1 from PL3 will be treated as hydrogen
# WARNING: atom H6C2 from PL3 will be treated as hydrogen
# WARNING: atom H6C2 from PL3 will be treated as hydrogen
# WARNING: atom H6C1 from PL3 will be treated as hydrogen
# WARNING: atom H6C1 from PL3 will be treated as hydrogen
# WARNING: atom H6C2 from PL3 will be treated as hydrogen
# WARNING: atom H6C1 from PL3 will be treated as hydrogen
# WARNING: atom H4C2 from PL3 will be treated as hydrogen
# WARNING: atom H4C2 from PL3 will be treated as hydrogen
# WARNING: atom H4C1 from PL3 will be treated as hydrogen
# WARNING: atom H4C1 from PL3 will be treated as hydrogen
# WARNING: atom H4C2 from PL3 will be treated as hydrogen
# WARNING: atom H4C1 from PL3 will be treated as hydrogen
# WARNING: atom H3C2 from PL3 will be treated as hydrogen
# WARNING: atom H3C2 from PL3 will be treated as hydrogen
# WARNING: atom H3C1 from PL3 will be treated as hydrogen
# WARNING: atom H3C1 from PL3 will be treated as hydrogen
# WARNING: atom H3C2 from PL3 will be treated as hydrogen
# WARNING: atom H3C1 from PL3 will be treated as hydrogen
# WARNING: atom H2C2 from PL3 will be treated as hydrogen
# WARNING: atom H2C2 from PL3 will be treated as hydrogen
# WARNING: atom H2C1 from PL3 will be treated as hydrogen
# WARNING: atom H2C1 from PL3 will be treated as hydrogen
# WARNING: atom H2C2 from PL3 will be treated as hydrogen
# WARNING: atom H2C1 from PL3 will be treated as hydrogen
# WARNING: atom H1C2 from PL3 will be treated as hydrogen
# WARNING: atom H1C2 from PL3 will be treated as hydrogen
# WARNING: atom H1C1 from PL3 will be treated as hydrogen
# WARNING: atom H1C1 from PL3 will be treated as hydrogen
# WARNING: atom H1C2 from PL3 will be treated as hydrogen
# WARNING: atom H1C1 from PL3 will be treated as hydrogen
# WARNING: A 221 PL3 O1   H atom too close to  A 221 PL3 C1   by 0.011267A
#         you may need to adjust using -METALBump or -NONMETALBump.
# SKIPPED H( A 221 PL3 HO  ): A 221 PL3 O1   bonds- A 221 PL3 C1   (short bond)
# Found 0 hydrogens (0 hets)
# Standardized 0 hydrogens (0 hets)
# Added 33 hydrogens (33 hets)
# Removed 0 hydrogens (0 hets)
# If you publish work which uses reduce, please cite:
# Word, et. al. (1999) J. Mol. Biol. 285, 1735-1747.
# For more information see http://kinemage.biochem.duke.edu
# 0

# %%
from biobb_chemistry.babelm.babel_minimize import babel_minimize

output_babel_min = ligandCode+'.H.min.mol2'

prop = {
    'method' : 'sd',
    'criteria' : '1e-10',
    'force_field' : 'GAFF'
}

babel_minimize(input_path=f"input/{output_reduce_h}",
              output_path=f"input/{output_babel_min}",
              properties=prop)
# Out:
# 2022-06-23 15:19:42,152 [MainThread  ] [INFO ]  Hydrogens  is not correct, assigned default value: False
# 2022-06-23 15:19:42,153 [MainThread  ] [INFO ]  Steps  is not correct, assigned default value: 2500
# 2022-06-23 15:19:42,154 [MainThread  ] [INFO ]  Cut-off  is not correct, assigned default value: False
# 2022-06-23 15:19:42,155 [MainThread  ] [INFO ]  Rvdw  is not correct, assigned default value: 6.0
# 2022-06-23 15:19:42,156 [MainThread  ] [INFO ]  Rele  is not correct, assigned default value: 10.0
# 2022-06-23 15:19:42,157 [MainThread  ] [INFO ]  Frequency  is not correct, assigned default value: 10
# 2022-06-23 15:19:42,159 [MainThread  ] [INFO ]  Not using any container
# 2022-06-23 15:19:43,635 [MainThread  ] [INFO ]  obminimize -c 1e-10 -sd -ff GAFF -ipdb input/pl3.reduce.H.pdb -omol2 > input/pl3.H.min.mol2
#
# 2022-06-23 15:19:43,637 [MainThread  ] [INFO ]  Exit code 0
#
# 2022-06-23 15:19:43,637 [MainThread  ] [INFO ]
# A T O M   T Y P E S
#
# IDX	TYPE	RING
# 1	c3	NO
# 2	c3	NO
# 3	c3	NO
# 4	c3	NO
# 5	c3	NO
# 6	c3	NO
# 7	oh	NO
# 8	c3	NO
# 9	c3	NO
# 10	c3	NO
# 11	c3	NO
# 12	c3	NO
# 13	c3	NO
# 14	c3	NO
# 15	c3	NO
# 16	c3	NO
# 17	c3	NO
# 18	hc	NO
# 19	hc	NO
# 20	hc	NO
# 21	hc	NO
# 22	hc	NO
# 23	hc	NO
# 24	hc	NO
# 25	hc	NO
# 26	hc	NO
# 27	hc	NO
# 28	hc	NO
# 29	hc	NO
# 30	hc	NO
# 31	hc	NO
# 32	hc	NO
# 33	hc	NO
# 34	hc	NO
# 35	hc	NO
# 36	hc	NO
# 37	hc	NO
# 38	hc	NO
# 39	hc	NO
# 40	hc	NO
# 41	hc	NO
# 42	hc	NO
# 43	hc	NO
# 44	hc	NO
# 45	hc	NO
# 46	hc	NO
# 47	hc	NO
# 48	hc	NO
# 49	h1	NO
# 50	h1	NO
#
# C H A R G E S
#
# IDX	CHARGE
# 1	-0.053057
# 2	-0.053057
# 3	-0.065276
# 4	-0.053065
# 5	-0.053306
# 6	0.082881
# 7	-0.234751
# 8	-0.026463
# 9	-0.050878
# 10	-0.052985
# 11	-0.053056
# 12	-0.053057
# 13	-0.053057
# 14	-0.053057
# 15	-0.053057
# 16	-0.053057
# 17	-0.055911
# 18	0.022978
# 19	0.022978
# 20	0.022978
# 21	0.026265
# 22	0.026265
# 23	0.026520
# 24	0.026520
# 25	0.026528
# 26	0.026528
# 27	0.026528
# 28	0.026528
# 29	0.026528
# 30	0.026528
# 31	0.026528
# 32	0.026528
# 33	0.026528
# 34	0.026528
# 35	0.026528
# 36	0.026528
# 37	0.026528
# 38	0.026528
# 39	0.026528
# 40	0.026528
# 41	0.026528
# 42	0.026528
# 43	0.026529
# 44	0.026529
# 45	0.026600
# 46	0.026600
# 47	0.028831
# 48	0.028831
# 49	0.059138
# 50	0.059138
#
# S E T T I N G   U P   C A L C U L A T I O N S
#
# SETTING UP BOND CALCULATIONS...
# SETTING UP ANGLE CALCULATIONS...
# SETTING UP TORSION CALCULATIONS...
# SETTING UP IMPROPER TORSION CALCULATIONS...
# SETTING UP VAN DER WAALS CALCULATIONS...
# SETTING UP ELECTROSTATIC CALCULATIONS...
#
# S T E E P E S T   D E S C E N T
#
# STEPS = 2500
#
# STEP n       E(n)         E(n-1)
# ------------------------------------
#     0     922.939      ----
#    10    124.46086    125.74078
#    20    116.84170    117.40572
#    30    112.29754    112.68218
#    40    109.03011    109.31654
#    50    106.52849    106.75291
#    60    104.52929    104.71139
#    70    102.88274    103.03457
#    80    101.49248    101.62202
#    90    100.29315    100.40592
#   100    99.23884    99.33877
#   110    98.29645    98.38640
#   120    97.44161    97.52371
#   130    96.65612    96.73197
#   140    95.92615    95.99698
#   150    95.24108    95.30782
#   160    94.59261    94.65602
#   170    93.97422    94.03487
#   180    93.38068    93.43905
#   190    92.80778    92.86425
#   200    92.25210    92.30698
#   210    91.71080    91.76436
#   220    91.18153    91.23398
#   230    90.66232    90.71384
#   240    90.15150    90.20226
#   250    89.64767    89.69778
#   260    89.14960    89.19918
#   270    88.65625    88.70540
#   280    88.16671    88.21552
#   290    87.68019    87.72874
#   300    87.19602    87.24435
#   310    86.71356    86.76175
#   320    86.23230    86.28040
#   330    85.75176    85.79980
#   340    85.27150    85.31953
#   350    84.79115    84.83921
#   360    84.31037    84.35849
#   370    83.82885    83.87705
#   380    83.34629    83.39461
#   390    82.86244    82.91090
#   400    82.37706    82.42568
#   410    81.88991    81.93872
#   420    81.40078    81.44980
#   430    80.90948    80.95872
#   440    80.41580    80.46530
#   450    79.91957    79.96933
#   460    79.42060    79.47064
#   470    78.91873    78.96906
#   480    78.41378    78.46443
#   490    77.90558    77.95657
#   500    77.39400    77.44533
#   510    76.87886    76.93055
#   520    76.36004    76.41211
#   530    75.83740    75.88985
#   540    75.31080    75.36366
#   550    74.78015    74.83342
#   560    74.24534    74.29903
#   570    73.70629    73.76040
#   580    73.16293    73.21748
#   590    72.61524    72.67022
#   600    72.06319    72.11861
#   610    71.50679    71.56264
#   620    70.94610    71.00238
#   630    70.38118    70.43788
#   640    69.81217    69.86927
#   650    69.23920    69.29669
#   660    68.66248    68.72033
#   670    68.08224    68.14044
#   680    67.49877    67.55728
#   690    66.91240    66.97118
#   700    66.32350    66.38252
#   710    65.73249    65.79170
#   720    65.13983    65.19918
#   730    64.54602    64.60547
#   740    63.95162    64.01110
#   750    63.35719    63.41664
#   760    62.76335    62.82272
#   770    62.17073    62.22995
#   780    61.58000    61.63900
#   790    60.99184    61.05056
#   800    60.40694    60.46529
#   810    59.82598    59.88391
#   820    59.24967    59.30710
#   830    58.67869    58.73556
#   840    58.11371    58.16995
#   850    57.55539    57.61094
#   860    57.00437    57.05916
#   870    56.46123    56.51521
#   880    55.92656    55.97967
#   890    55.40086    55.45305
#   900    54.88464    54.93586
#   910    54.37832    54.42853
#   920    53.88229    53.93146
#   930    53.39689    53.44498
#   940    52.92239    52.96938
#   950    52.45904    52.50491
#   960    52.00700    52.05173
#   970    51.56638    51.60997
#   980    51.13726    51.17969
#   990    50.71964    50.76092
#  1000    50.31347    50.35362
#  1010    49.91867    49.95769
#  1020    49.53509    49.57299
#  1030    49.16254    49.19935
#  1040    48.80079    48.83652
#  1050    48.44956    48.48425
#  1060    48.10853    48.14223
#  1070    47.77738    47.81010
#  1080    47.45571    47.48750
#  1090    47.14312    47.17403
#  1100    46.83919    46.86925
#  1110    46.54347    46.57273
#  1120    46.25549    46.28399
#  1130    45.97476    46.00257
#  1140    45.70082    45.72796
#  1150    45.43314    45.45968
#  1160    45.17124    45.19723
#  1170    44.91459    44.94008
#  1180    44.66270    44.68773
#  1190    44.41504    44.43967
#  1200    44.17109    44.19538
#  1210    43.93034    43.95434
#  1220    43.69226    43.71601
#  1230    43.45631    43.47987
#  1240    43.22524    43.24683
#  1250    43.08473    43.09558
#  1260    42.97741    42.98809
#  1270    42.87138    42.88194
#  1280    42.76654    42.77698
#  1290    42.66283    42.67316
#  1300    42.56018    42.57041
#  1310    42.45854    42.46867
#  1320    42.35785    42.36789
#  1330    42.25805    42.26800
#  1340    42.15909    42.16896
#  1350    42.06091    42.07071
#  1360    41.96346    41.97318
#  1370    41.86668    41.87634
#  1380    41.77052    41.78012
#  1390    41.67493    41.68447
#  1400    41.57984    41.58934
#  1410    41.48520    41.49466
#  1420    41.39096    41.40038
#  1430    41.29706    41.30645
#  1440    41.20344    41.21280
#  1450    41.11004    41.11938
#  1460    41.01679    41.02612
#  1470    40.92363    40.93295
#  1480    40.83049    40.83982
#  1490    40.73731    40.74664
#  1500    40.64400    40.65335
#  1510    40.55049    40.55987
#  1520    40.45669    40.46610
#  1530    40.36252    40.37197
#  1540    40.26788    40.27738
#  1550    40.17266    40.18223
#  1560    40.07676    40.08640
#  1570    39.98005    39.98978
#  1580    39.88241    39.89224
#  1590    39.78368    39.79363
#  1600    39.68371    39.69379
#  1610    39.58232    39.59255
#  1620    39.48062    39.49031
#  1630    39.41531    39.42034
#  1640    39.36531    39.37031
#  1650    39.31542    39.32041
#  1660    39.26558    39.27056
#  1670    39.21577    39.22075
#  1680    39.16599    39.17097
#  1690    39.11621    39.12119
#  1700    39.06642    39.07141
#  1710    39.01661    39.02160
#  1720    38.96677    38.97176
#  1730    38.91686    38.92186
#  1740    38.86688    38.87189
#  1750    38.81681    38.82182
#  1760    38.76662    38.77165
#  1770    38.71631    38.72135
#  1780    38.66585    38.67091
#  1790    38.61522    38.62029
#  1800    38.56439    38.56949
#  1810    38.51335    38.51847
#  1820    38.46208    38.46722
#  1830    38.41053    38.41571
#  1840    38.35870    38.36391
#  1850    38.30655    38.31179
#  1860    38.25405    38.25932
#  1870    38.20117    38.20648
#  1880    38.14787    38.15323
#  1890    38.09413    38.09953
#  1900    38.03989    38.04534
#  1910    37.98512    37.99063
#  1920    37.92976    37.93534
#  1930    37.87378    37.87942
#  1940    37.81712    37.82283
#  1950    37.75971    37.76550
#  1960    37.70150    37.70737
#  1970    37.64240    37.64836
#  1980    37.58234    37.58840
#  1990    37.52132    37.52744
#  2000    37.47267    37.47586
#  2010    37.44252    37.44552
#  2020    37.41263    37.41562
#  2030    37.38276    37.38575
#  2040    37.35290    37.35589
#  2050    37.32306    37.32605
#  2060    37.29322    37.29621
#  2070    37.26338    37.26637
#  2080    37.23354    37.23653
#  2090    37.20369    37.20668
#  2100    37.17382    37.17681
#  2110    37.14392    37.14691
#  2120    37.11399    37.11699
#  2130    37.08403    37.08703
#  2140    37.05401    37.05702
#  2150    37.02394    37.02696
#  2160    36.99381    36.99683
#  2170    36.96360    36.96663
#  2180    36.93331    36.93635
#  2190    36.90292    36.90597
#  2200    36.87243    36.87549
#  2210    36.84182    36.84489
#  2220    36.81108    36.81416
#  2230    36.78019    36.78329
#  2240    36.74914    36.75225
#  2250    36.71791    36.72104
#  2260    36.68648    36.68964
#  2270    36.65484    36.65802
#  2280    36.62295    36.62616
#  2290    36.59081    36.59404
#  2300    36.55837    36.56164
#  2310    36.52562    36.52892
#  2320    36.49252    36.49585
#  2330    36.45903    36.46241
#  2340    36.42512    36.42854
#  2350    36.39074    36.39421
#  2360    36.35586    36.35937
#  2370    36.32550    36.32752
#  2380    36.30791    36.30963
#  2390    36.29077    36.29248
#  2400    36.27365    36.27536
#  2410    36.25655    36.25826
#  2420    36.23947    36.24118
#  2430    36.22240    36.22411
#  2440    36.20534    36.20705
#  2450    36.18829    36.19000
#  2460    36.17124    36.17295
#  2470    36.15418    36.15589
#  2480    36.13712    36.13883
#  2490    36.12004    36.12175
#  2500    36.10294    36.10465
# Time: 1.05412seconds. Iterations per second: 2372.59
# 0

# %%
view1 = nglview.show_structure_file(f"input/{ligandFile}")
view1.add_representation(repr_type='ball+stick')
view1._remote_call('setSize', target='Widget', args=['350px','400px'])
view1.camera='orthographic'

view1
view2 = nglview.show_structure_file(f"input/{output_reduce_h}")
view2.add_representation(repr_type='ball+stick')
view2._remote_call('setSize', target='Widget', args=['350px','400px'])
view2.camera='orthographic'

view2
view3 = nglview.show_structure_file(f"input/{output_babel_min}")
view3.add_representation(repr_type='ball+stick')
view3._remote_call('setSize', target='Widget', args=['350px','400px'])
view3.camera='orthographic'

view3
ipywidgets.HBox([view1, view2, view3])
# Out:
# HBox(children=(NGLWidget(), NGLWidget(), NGLWidget()))

# %%
from biobb_chemistry.acpype.acpype_params_ac import acpype_params_ac

output_acpype_inpcrd = ligandCode+'params.inpcrd'
output_acpype_frcmod = ligandCode+'params.frcmod'
output_acpype_lib = ligandCode+'params.lib'
output_acpype_prmtop = ligandCode+'params.prmtop'
output_acpype = ligandCode+'params'

prop = {
    'basename' : output_acpype,
    'charge' : None
}

acpype_params_ac(input_path=f"input/{output_babel_min}", 
                output_path_inpcrd=f"input/{output_acpype_inpcrd}",
                output_path_frcmod=f"input/{output_acpype_frcmod}",
                output_path_lib=f"input/{output_acpype_lib}",
                output_path_prmtop=f"input/{output_acpype_prmtop}",
                properties=prop)
# Out:
# 2022-06-23 15:19:53,262 [MainThread  ] [INFO ]  Charge will be guessed by acpype.
# 2022-06-23 15:19:53,263 [MainThread  ] [INFO ]  Running acpype, this execution can take a while
# 2022-06-23 15:19:53,264 [MainThread  ] [INFO ]  Not using any container
# 2022-06-23 15:20:38,995 [MainThread  ] [INFO ]  acpype -i /Users/ethan/LatchBio/input/pl3.H.min.mol2 -b pl3params.ahSW43
#
# 2022-06-23 15:20:39,000 [MainThread  ] [INFO ]  Exit code 0
#
# 2022-06-23 15:20:39,002 [MainThread  ] [INFO ]  ========================================================================================
# | ACPYPE: AnteChamber PYthon Parser interfacE v. 2019-11-07T23:16:00CET (c) 2022 AWSdS |
# ========================================================================================
# WARNING: no charge value given, trying to guess one...
# ==> ... charge set to -1
# ==> Executing Antechamber...
# ==> * Antechamber OK *
# ==> * Parmchk OK *
# ==> Executing Tleap...
# ++++++++++start_quote+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Checking 'PL3'....
#
# /Users/ethan/anaconda3/envs/biobb_AMBER_MD/bin/teLeap: Warning!
# The unperturbed charge of the unit (-0.999999) is not zero.
# Checking parameters for unit 'PL3'.
# Checking for bond parameters.
# Checking for angle parameters.
# check:  Warnings: 1
# Unit is OK.
# ++++++++++end_quote+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ==> * Tleap OK *
# ==> Removing temporary files...
# ==> Writing NEW PDB file
#
# ==> Writing CNS/XPLOR files
#
# ==> Writing GROMACS files
#
# ==> Writing GMX dihedrals for GMX 4.5 and higher.
#
# ==> Writing CHARMM files
#
# ==> Writing pickle file pl3params.ahSW43.pkl
# Total time of execution: 46s
#
# 2022-06-23 15:20:39,010 [MainThread  ] [INFO ]  File input/pl3params.frcmod succesfully created
# 2022-06-23 15:20:39,017 [MainThread  ] [INFO ]  File input/pl3params.prmtop succesfully created
# 2022-06-23 15:20:39,024 [MainThread  ] [INFO ]  File input/pl3params.inpcrd succesfully created
# 2022-06-23 15:20:39,035 [MainThread  ] [INFO ]  File input/pl3params.lib succesfully created
# 2022-06-23 15:20:39,061 [MainThread  ] [INFO ]  Removed temporary folder: pl3params.ahSW43.acpype
# 0
